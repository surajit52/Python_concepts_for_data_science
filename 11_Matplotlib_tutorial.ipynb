# %% [markdown]
# # MatplotLib Tutorial

# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

#in jupyter notebook if we dont write the above line(%matplotlib inline) we have to write plt.show so to aboid that we write the above line.

# %%
import numpy as np

# %%
x= np.arange(0,10)
y= np.arange(11,21)

# %%
a= np.arange(40,50)
b= np.arange(50,60)

# %%
#sctter plot is used to scatter values of x and y
#prees shift tab tosee the attributes
#x, y is data values
# c is colour attribute
# s is solid attribute value
# Here g means green color

# %%
plt.scatter(x,y, c='g')

#as inline function is written above
#no need to write plt.show
#for other tools we have to probably write plt.show
#plt.xlabel (gives the x axis name)
#plt.ylabel (gives the y axis name)
#plt.title (gives the name for the graph)

# %%
plt.scatter(x,y, c='g')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
#plt.plot will help to draw fixed straight lline plot

# %%
plt.plot(x,y)

# %%
#let get us a parbola plot

y= x*x

# %%
plt.plot(x,y)
#by deafult blue colour

# %%
plt.plot(x,y)
#by dotted re d colour
# r specifies re colur
#r- specifes dotted red

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'r-*')

# %%
#just check documnentation with shift tab
#dashed linestyle graph

plt.plot(x,y,'r*',linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %%
#subplot
#subplots means within on ecanvas we can draw multple subplot
#subplot takes minimum 3 parameters nrows,ncolumns,position of n=2 means at 4 positions i can make subplots or sub diagrams of plot function, Position means at whixh position we want what diagram

#for 1st quadrant
plt.subplot(2,2,1)
plt.plot(x,y,'r')
#for 2nd quadrant
plt.subplot(2,2,2)
plt.plot(x,y,'b--')
#for 3rd quadrant
plt.subplot(2,2,3)
plt.plot(x,y,'g*')
#for 4th quadrant
plt.subplot(2,2,4)
plt.plot(x,y,'y-o')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')
plt.subplot(2,2,2)
plt.plot(x,y,'b--')
plt.subplot(2,2,3)
plt.plot(x,y,'g*')
plt.subplot(2,2,4)
plt.plot(x,y,'y-*')
plt.subplot(2,2,5)
plt.plot(x,y,'g-*')
#here we passes 2,2 columns rows means we created total of 2*2=4 quadrant and forcefully tried to pass informatio  for 5th plot hence we got the error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c913806422c3> in <module>
#       7 plt.subplot(2,2,4)
#       8 plt.plot(x,y,'y-*')
# ----> 9 plt.subplot(2,2,5)
#      10 plt.plot(x,y,'g-*')
#      11 #here we passes 2,2 columns rows means we created total of 2*2=4 quadrant and forcefully tried to pass informatio  for 5th plot hence we got the error
#
# D:\Drivers\Anaconda\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# D:\Drivers\Anaconda\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
# ...

# %%
#passing x column information aas a range from 1 to 10
x =np.arange(1,10)
y = 5*(x)+15
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('matplotlib Diagram')
plt.plot(x,y,'r')

# %%
#Creating sinewave from o to 4pie like in math

# %%
#defininhg the valu of pi using numpy
np.pi
# Out:
# 3.141592653589793

# %%
#Here we want x to be in range from 0 to 4pi and 0.1 is step size
x = np.arange(0,4*np.pi, 0.1)
y = np.sin(x)
#her np.sin will teel pythin to use trignometric sin function

plt.plot(x,y)
plt.title('Sine Wave Diagram')
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  


# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
##Bar Plot
x = [2,8,10]
y = [11,16,9]

x2= [3,9,11]
y2= [6,15,7]

plt.bar(x,y)
plt.bar(x2,y2, color = 'g')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.title('Bar Graph')
plt.show()

# %% [markdown]
# # Histogram

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

#we have a range of values and histogram says what is the density or count of no. within particular range(bins)
#range 0-20 we have three no.s 5,11,20 so and 1 count which is 20

# %% [markdown]
# # Box Plot Using Matplotlib

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

#rectangular box plot
plt.boxplot(data, vert=True, patch_artist= True);

#vert=True makes box plot vertical
#Patch_artist =True gies blue color in box plot

# %% [markdown]
# # Pie Chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()

# %%
#sizes calculates the total percentage of individual elements

215+130+245+210
# Out:
# 800

# %%
215/800
# Out:
# 0.26875

# %%
#explode separeates the pie apart by some distance
#python pie is separated by 0.4 units
#autopct = %1.1f%% allows how to represent percent with just one decimmal point
#shadows =true gives the grey shadow beneath each pie.
